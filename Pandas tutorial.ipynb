# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("IPL Matches 2008-2020.csv")

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df.tail()
# Out:
#           id       city        date player_of_match  \
# 811  1216547      Dubai  2020-09-28  AB de Villiers
# 812  1237177      Dubai  2020-11-05       JJ Bumrah
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 811  Dubai International Cricket Stadium              0
# 812  Dubai International Cricket Stadium              0
# 813                 Sheikh Zayed Stadium              0
# 814                 Sheikh Zayed Stadium              0
# 815  Dubai International Cricket Stadium              0
#
#                            team1                team2          toss_winner  \
# 811  Royal Challengers Bangalore       Mumbai Indians       Mumbai Indians
# 812               Mumbai Indians       Delhi Capitals       Delhi Capitals
# 813  Royal Challengers Bangalore  Sunrisers Hyderabad  Sunrisers Hyderabad
# ...

# %%
df.shape
# Out:
# (816, 17)

# %%
df.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
df.iloc[0:10,1:3]
# Out:
#          city        date
# 0   Bangalore  2008-04-18
# 1  Chandigarh  2008-04-19
# 2       Delhi  2008-04-19
# 3      Mumbai  2008-04-20
# 4     Kolkata  2008-04-20
# 5      Jaipur  2008-04-21
# 6   Hyderabad  2008-04-22
# 7     Chennai  2008-04-23
# 8   Hyderabad  2008-04-24
# 9  Chandigarh  2008-04-25

# %%
df.loc[1:10,("player_of_match","city")]
# Out:
#    player_of_match        city
# 1       MEK Hussey  Chandigarh
# 2      MF Maharoof       Delhi
# 3       MV Boucher      Mumbai
# 4        DJ Hussey     Kolkata
# 5        SR Watson      Jaipur
# 6         V Sehwag   Hyderabad
# 7        ML Hayden     Chennai
# 8        YK Pathan   Hyderabad
# 9    KC Sangakkara  Chandigarh
# 10       SR Watson   Bangalore

# %%
df.drop('neutral_venue',axis=1)
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1    Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                              Feroz Shah Kotla             Delhi Daredevils
# ...

# %%
df.drop([1,2,3],axis=0)
# Out:
#           id       city        date player_of_match  \
# 0     335982  Bangalore  2008-04-18     BB McCullum
# 4     335986    Kolkata  2008-04-20       DJ Hussey
# 5     335987     Jaipur  2008-04-21       SR Watson
# 6     335988  Hyderabad  2008-04-22        V Sehwag
# 7     335989    Chennai  2008-04-23       ML Hayden
# ..       ...        ...         ...             ...
# 811  1216547      Dubai  2020-09-28  AB de Villiers
# 812  1237177      Dubai  2020-11-05       JJ Bumrah
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                          venue  neutral_venue  \
# 0                        M Chinnaswamy Stadium              0
# 4                                 Eden Gardens              0
# 5                       Sawai Mansingh Stadium              0
# 6    Rajiv Gandhi International Stadium, Uppal              0
# ...

# %%
df.mean()
# Out:
# id               756349.553922
# neutral_venue         0.094363
# result_margin        17.321652
# dtype: float64

# %%
df.median()
# Out:
# id               729298.0
# neutral_venue         0.0
# result_margin         8.0
# dtype: float64

# %%
df.min()
# Out:
# id                            335982
# date                      2008-04-18
# venue               Barabati Stadium
# neutral_venue                      0
# team1            Chennai Super Kings
# team2            Chennai Super Kings
# toss_winner      Chennai Super Kings
# toss_decision                    bat
# result_margin                      1
# umpire1                   A Deshmukh
# umpire2                   A Deshmukh
# dtype: object

# %%
df.max()
# Out:
# id                           1237181
# date                      2020-11-10
# venue               Wankhede Stadium
# neutral_venue                      1
# team1            Sunrisers Hyderabad
# team2            Sunrisers Hyderabad
# toss_winner      Sunrisers Hyderabad
# toss_decision                  field
# result_margin                    146
# umpire1                     YC Barde
# umpire2                     YC Barde
# dtype: object

# %%
def double_value(s):
    return s*2

# %%
df[['result_margin']].apply(double_value)
# Out:
#      result_margin
# 0            280.0
# 1             66.0
# 2             18.0
# 3             10.0
# 4             10.0
# ..             ...
# 811            NaN
# 812          114.0
# 813           12.0
# 814           34.0
# 815           10.0
#
# [816 rows x 1 columns]

# %%
df['winner'].value_counts()
# Out:
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
df.sort_values(by='winner')
# Out:
#           id       city        date player_of_match  \
# 386   598062    Chennai  2013-05-14        MS Dhoni
# 455   734045     Mumbai  2014-05-28        SK Raina
# 122   419113    Kolkata  2010-03-16        MS Dhoni
# 204   501228     Mumbai  2011-04-27    DE Bollinger
# 700  1175360      Delhi  2019-03-26       SR Watson
# ..       ...        ...         ...             ...
# 674  1136599  Hyderabad  2018-05-07   KS Williamson
# 241   501265      Delhi  2011-05-21             NaN
# 486   829763  Bangalore  2015-04-29             NaN
# 511   829813  Bangalore  2015-05-17             NaN
# 744  1178424  Bengaluru  2019-04-30             NaN
#
#                                          venue  neutral_venue  \
# 386            MA Chidambaram Stadium, Chepauk              0
# 455                          Brabourne Stadium              0
# 122                               Eden Gardens              0
# 204                 Dr DY Patil Sports Academy              0
# ...
